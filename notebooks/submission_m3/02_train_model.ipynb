# %% [markdown]
# # Train model

# %% [markdown]
# ### Imports

# %%
import os
if 'notebooks' in os.getcwd(): os.chdir('../..')  # change to main directory
print('Working directory:', os.getcwd() )
# Out:
# Working directory: /scratch/snx3000/bp000429/submission/adrian_sensorium

# %%
import torch
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from nnfabrik.builder import get_data, get_model, get_trainer

from sensorium.utility.training import read_config, print_t, set_seed
from sensorium.utility import prediction

# %% [markdown]
# ### Load configuration for model

# %%
config_file = 'notebooks/submission_m3/config_submission_m3.yaml'
config = read_config( config_file )
print(config)
# Out:
# ordereddict([('data_sets', ['all']), ('dataset_fn', 'sensorium.datasets.static_loaders'), ('dataset_config', ordereddict([('normalize', True), ('include_behavior', True), ('include_eye_position', True), ('batch_size', 128), ('scale', 0.25), ('preload_from_merged_data', True), ('include_trial_id', True), ('include_rank_id', True), ('include_history', True), ('include_behav_state', True), ('adjusted_normalization', True)])), ('model_fn', 'sensorium.models.modulated_stacked_core_full_gauss_readout'), ('model_seed', 3452), ('model_config', ordereddict([('pad_input', False), ('stack', -1), ('layers', 4), ('input_kern', 9), ('gamma_input', 9.8), ('gamma_readout', 0.48), ('hidden_kern', 10), ('hidden_channels', 64), ('depth_separable', True), ('grid_mean_predictor', ordereddict([('type', 'cortex'), ('input_dimensions', 2), ('hidden_layers', 4), ('hidden_features', 20), ('nonlinearity', 'ReLU'), ('final_tanh', True)])), ('init_sigma', 0.14), ('init_mu_range', 0.8), ('gauss_type', 'full'), ('shifter', True), ('with_modulator', True), ('modulator_type', 'HistoryStateGain'), ('modulator_params', ordereddict([('include_gain', True), ('gain_kernel_std', 30), ('diff_reg', 100), ('include_history', True), ('nr_history', 5), ('behav_state', True), ('nr_behav_state', 10), ('per_neuron_gain_adjust', True), ('gain_adjust_alpha', 0.3), ('alpha_behav', 0.3), ('alpha_hist', 0.3)]))])), ('use_pretrained_core', False), ('pretrained_model_file', 'no_file'), ('trainer_fn', 'sensorium.training.standard_trainer'), ('trainer_config', ordereddict([('max_iter', 200), ('verbose', True), ('lr_decay_steps', 4), ('avg_loss', False), ('lr_init', 0.009), ('track_training', True), ('disable_tqdm', True)])), ('verbose', 3), ('save_csv', True), ('save_predictions_npy', True)])

# %% [markdown]
# ### Prepare dataloader

# %%
set_seed( config['model_seed'] )  # seed all random generators

if config['data_sets'][0] == 'all':
    basepath = "notebooks/data/"
    filenames = [os.path.join(basepath, file) for file in os.listdir(basepath) if ".zip" in file ]
    filenames = [file for file in filenames if 'static26872-17-20' not in file]
else:
    filenames = config['data_sets']
    # filenames like ['notebooks/data/static21067-10-18-GrayImageNet-94c6ff995dac583098847cfecd43e7b6.zip', ]
    
dataset_fn = config['dataset_fn']  # 'sensorium.datasets.static_loaders'
dataset_config = {'paths': filenames,
                  **config['dataset_config'],
                 }

dataloaders = get_data(dataset_fn, dataset_config)

# %% [markdown]
# ### Instantiate model and trainer

# %%
# Instantiate model
model_fn = config['model_fn']     # e.g. 'sensorium.models.modulated_stacked_core_full_gauss_readout'
model_config = config['model_config']

model = get_model(model_fn=model_fn,
                  model_config=model_config,
                  dataloaders=dataloaders,
                  seed=config['model_seed'],
                 )

# Trainer
trainer_fn = config['trainer_fn']   # "sensorium.training.standard_trainer"
trainer_config = config['trainer_config']

trainer = get_trainer(trainer_fn=trainer_fn, 
                     trainer_config=trainer_config)

# %% [markdown]
# ### Train model

# %%
print_t('Start of model training')
validation_score, trainer_output, state_dict = trainer(model, dataloaders, seed=42)
print_t('Model training finished')

save_file = 'notebooks/submission_m3/results/model_v3.pth'
torch.save(model.state_dict(), save_file )
# Out:
# 2022-10-12 15:09:39.090882: Start of model training
# =======================================
# correlation 0.019702673
# poisson_loss 28384930.0
# =======================================
# correlation 0.16340499
# poisson_loss 15555482.0
# =======================================
# correlation 0.21689159
# poisson_loss 14941753.0
# =======================================
# correlation 0.24678558
# poisson_loss 14581655.0
# =======================================
# correlation 0.27456275
# poisson_loss 14235428.0
# =======================================
# correlation 0.29427832
# poisson_loss 13956108.0
# =======================================
# correlation 0.31595892
# poisson_loss 13684575.0
# =======================================
# correlation 0.33865714
# poisson_loss 13384968.0
# =======================================
# correlation 0.35921317
# poisson_loss 13128105.0
# =======================================
# correlation 0.37086836
# poisson_loss 12980786.0
# =======================================
# correlation 0.37931454
# poisson_loss 12881538.0
# =======================================
# correlation 0.38665688
# poisson_loss 12785906.0
# =======================================
# correlation 0.39331934
# poisson_loss 12709832.0
# =======================================
# correlation 0.4005654
# poisson_loss 12613548.0
# =======================================
# correlation 0.4048122
# poisson_loss 12574420.0
# =======================================
# correlation 0.40934557
# poisson_loss 12512138.0
# =======================================
# correlation 0.41198575
# poisson_loss 12481812.0
# =======================================
# correlation 0.41715196
# poisson_loss 12418844.0
# =======================================
# correlation 0.42021087
# poisson_loss 12376063.0
# =======================================
# correlation 0.42490163
# poisson_loss 12323685.0
# =======================================
# correlation 0.42525008
# poisson_loss 12317176.0
# =======================================
# correlation 0.42904714
# poisson_loss 12268607.0
# =======================================
# correlation 0.43052897
# poisson_loss 12248501.0
# =======================================
# correlation 0.432671
# poisson_loss 12237892.0
# =======================================
# correlation 0.4348791
# poisson_loss 12201780.0
# =======================================
# correlation 0.43645012
# poisson_loss 12185428.0
# =======================================
# correlation 0.4363237
# poisson_loss 12183219.0
# =======================================
# correlation 0.43931356
# poisson_loss 12143721.0
# =======================================
# correlation 0.4397225
# poisson_loss 12139450.0
# =======================================
# correlation 0.4427232
# poisson_loss 12109420.0
# =======================================
# correlation 0.44036788
# poisson_loss 12148448.0
# =======================================
# correlation 0.443318
# poisson_loss 12107146.0
# =======================================
# correlation 0.4454782
# poisson_loss 12080383.0
# =======================================
# correlation 0.44483846
# poisson_loss 12086700.0
# =======================================
# correlation 0.44655132
# poisson_loss 12062933.0
# =======================================
# correlation 0.4483031
# poisson_loss 12034388.0
# =======================================
# correlation 0.44794762
# poisson_loss 12055834.0
# =======================================
# correlation 0.44735003
# poisson_loss 12065330.0
# =======================================
# correlation 0.4493336
# poisson_loss 12040382.0
# =======================================
# correlation 0.44931293
# poisson_loss 12037725.0
# =======================================
# correlation 0.45053813
# poisson_loss 12024206.0
# =======================================
# correlation 0.45164165
# poisson_loss 12007494.0
# =======================================
# correlation 0.4530684
# poisson_loss 11992765.0
# =======================================
# correlation 0.45303625
# poisson_loss 11995920.0
# =======================================
# correlation 0.45349017
# poisson_loss 11990596.0
# =======================================
# correlation 0.45352095
# poisson_loss 11994514.0
# =======================================
# correlation 0.45396003
# poisson_loss 11985996.0
# =======================================
# correlation 0.45447168
# poisson_loss 11981096.0
# =======================================
# correlation 0.4552016
# poisson_loss 11964510.0
# =======================================
# correlation 0.456136
# poisson_loss 11962228.0
# =======================================
# correlation 0.4551677
# poisson_loss 11977099.0
# =======================================
# correlation 0.45583197
# poisson_loss 11963623.0
# =======================================
# correlation 0.4563983
# poisson_loss 11959102.0
# =======================================
# correlation 0.4571283
# poisson_loss 11950356.0
# =======================================
# correlation 0.45733577
# poisson_loss 11947111.0
# =======================================
# correlation 0.45721406
# poisson_loss 11949738.0
# =======================================
# correlation 0.4585015
# poisson_loss 11936309.0
# =======================================
# correlation 0.45648545
# poisson_loss 11951849.0
# =======================================
# correlation 0.4571534
# poisson_loss 11950007.0
# =======================================
# correlation 0.4597333
# poisson_loss 11923429.0
# =======================================
# correlation 0.4585497
# poisson_loss 11930812.0
# =======================================
# correlation 0.45850927
# poisson_loss 11933550.0
# =======================================
# correlation 0.45853516
# poisson_loss 11931284.0
# =======================================
# correlation 0.4589309
# poisson_loss 11934426.0
# =======================================
# correlation 0.45957854
# poisson_loss 11924450.0
# Epoch    65: reducing learning rate of group 0 to 2.7000e-03.
# =======================================
# correlation 0.4582624
# poisson_loss 11931358.0
# =======================================
# correlation 0.46876854
# poisson_loss 11792498.0
# =======================================
# correlation 0.46852395
# poisson_loss 11799490.0
# =======================================
# correlation 0.46893436
# poisson_loss 11796231.0
# =======================================
# correlation 0.46908525
# poisson_loss 11791926.0
# =======================================
# correlation 0.46912464
# poisson_loss 11796406.0
# =======================================
# correlation 0.46948954
# poisson_loss 11788171.0
# =======================================
# correlation 0.4691885
# poisson_loss 11794760.0
# =======================================
# correlation 0.46918243
# poisson_loss 11797966.0
# =======================================
# correlation 0.4693368
# poisson_loss 11796681.0
# =======================================
# correlation 0.4694172
# poisson_loss 11795623.0
# =======================================
# correlation 0.46945524
# poisson_loss 11788540.0
# Epoch    77: reducing learning rate of group 0 to 8.1000e-04.
# =======================================
# correlation 0.46928
# poisson_loss 11794325.0
# =======================================
# correlation 0.4713758
# poisson_loss 11765126.0
# =======================================
# correlation 0.471501
# poisson_loss 11763091.0
# =======================================
# correlation 0.47159547
# poisson_loss 11764318.0
# =======================================
# correlation 0.47168925
# poisson_loss 11763256.0
# =======================================
# correlation 0.4717602
# poisson_loss 11763128.0
# =======================================
# correlation 0.4716586
# poisson_loss 11762396.0
# =======================================
# correlation 0.47171435
# poisson_loss 11765739.0
# =======================================
# correlation 0.47191006
# poisson_loss 11763393.0
# =======================================
# correlation 0.47171468
# poisson_loss 11766755.0
# =======================================
# correlation 0.47159562
# poisson_loss 11763233.0
# =======================================
# correlation 0.4718476
# poisson_loss 11764136.0
# =======================================
# correlation 0.47189733
# poisson_loss 11762732.0
# =======================================
# correlation 0.471423
# poisson_loss 11766925.0
# =======================================
# correlation 0.47177383
# poisson_loss 11765260.0
# =======================================
# correlation 0.47166866
# poisson_loss 11766316.0
# =======================================
# correlation 0.47165564
# poisson_loss 11767662.0
# =======================================
# correlation 0.47166133
# poisson_loss 11765079.0
# =======================================
# correlation 0.4717005
# poisson_loss 11765919.0
# =======================================
# correlation 0.4718622
# poisson_loss 11765671.0
# =======================================
# correlation 0.47165963
# poisson_loss 11766436.0
# Epoch    98: reducing learning rate of group 0 to 2.4300e-04.
# =======================================
# correlation 0.47165263
# poisson_loss 11768690.0
# =======================================
# correlation 0.47224674
# poisson_loss 11759152.0
# =======================================
# correlation 0.47234657
# poisson_loss 11757676.0
# =======================================
# correlation 0.47235048
# poisson_loss 11758984.0
# =======================================
# correlation 0.47240657
# poisson_loss 11757524.0
# =======================================
# correlation 0.4725095
# poisson_loss 11757347.0
# =======================================
# correlation 0.47259435
# poisson_loss 11756534.0
# =======================================
# correlation 0.47247285
# poisson_loss 11758314.0
# =======================================
# correlation 0.4724976
# poisson_loss 11757930.0
# =======================================
# correlation 0.47255477
# poisson_loss 11756806.0
# =======================================
# correlation 0.4724852
# poisson_loss 11758498.0
# =======================================
# correlation 0.47255164
# poisson_loss 11757012.0
# =======================================
# correlation 0.47256652
# poisson_loss 11757398.0
# =======================================
# correlation 0.4724714
# poisson_loss 11759100.0
# 2022-10-12 18:31:15.489816: Model training finished

# %% [markdown]
# ### Save all predictions as .npy

# %%
if config['save_predictions_npy']:
    # calculate predictions per dataloader
    results = prediction.all_predictions_with_trial(model, dataloaders)

    # merge predictions, sort in time and add behavioral variables
    merged = prediction.merge_predictions(results)
    sorted_res = prediction.sort_predictions_by_time(merged)
    prediction.inplace_add_behavior_to_sorted_predictions(sorted_res)
    
    npy_file = 'notebooks/submission_m3/results/prediction_model_v3.npy'
    np.save( npy_file, sorted_res)
# Out:
# Iterating datasets: 100%|██████████| 6/6 [01:20<00:00, 13.37s/it]
